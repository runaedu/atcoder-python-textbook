# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# We love golf<p>
# 問題文と提出先　https://atcoder.jp/contests/abc165/tasks/abc165_a

# %%
# %%writefile atcoder.py
def in2ilist():
  return list(map(int,input().split()))

K=int(input())
A,B=in2ilist()
res="NG"

for i in range(A,B+1):
  if i%K==0:
    res="OK"
print(res)
# Out:
# Writing atcoder.py

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 7
# 500 600
# Out:
# Writing test1

# %%
# %cat test1 | python3 atcoder.py
# Out:
# OK

# %% [markdown]
# OK

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 4
# 5 7
# Out:
# Writing test2

# %%
# %cat test2 | python3 atcoder.py
# Out:
# NG

# %% [markdown]
# NG

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# 1
# 11 11
# Out:
# Overwriting test3

# %%
# %cat test3 | python3 atcoder.py
# Out:
# OK

# %% [markdown]
# OK

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A
