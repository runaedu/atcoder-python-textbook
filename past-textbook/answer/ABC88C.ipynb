# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# Takahashi's Information<p>
# 問題文と提出先　 https://atcoder.jp/contests/abc088/tasks/abc088_c

# %% [markdown]
# 本文と違い、2次元配列を読み込む専用の関数を準備します。<p>
# def in2ihw(_h): <p>

# %%
# %%writefile atcoder.py
def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

C=in2ihw(3)
ans="Yes"
if C[0][0]-C[0][1]!=C[1][0]-C[1][1] or C[1][0]-C[1][1]!=C[2][0]-C[2][1]:
  ans="No"
if C[0][1]-C[0][2]!=C[1][1]-C[1][2] or C[1][1]-C[1][2]!=C[2][1]-C[2][2]:
  ans="No"
if C[0][0]-C[1][0]!=C[0][1]-C[1][1] or C[0][1]-C[1][1]!=C[0][2]-C[1][2]:
  ans="No"
if C[1][0]-C[2][0]!=C[1][1]-C[2][1] or C[1][1]-C[2][1]!=C[1][2]-C[2][2]:
  ans="No"

print(ans)
# Out:
# Overwriting atcoder.py

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 1 0 1
# 2 1 2
# 1 0 1
# Out:
# Writing test1

# %%
# %cat test1 | python3 atcoder.py
# Out:
# Yes

# %% [markdown]
# Yes

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 2 2 2
# 2 1 2
# 2 2 2
# Out:
# Writing test2

# %%
# %cat test2 | python3 atcoder.py
# Out:
# No

# %% [markdown]
# No

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# 0 8 8
# 0 8 8
# 0 8 8
# Out:
# Writing test3

# %%
# %cat test3 | python3 atcoder.py
# Out:
# Yes

# %% [markdown]
# Yes

# %% [markdown]
# # 入力例4

# %%
# %%writefile test4
# 1 8 6
# 2 9 7
# 0 7 7
# Out:
# Writing test4

# %%
# %cat test4 | python3 atcoder.py
# Out:
# No

# %% [markdown]
# No

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。
