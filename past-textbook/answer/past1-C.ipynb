# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# 3番目<p>
# 問題文と提出先　 https://atcoder.jp/contests/past201912-open/tasks/past201912_c

# %%
# %%writefile atcoder.py

a=list(map(int,input().split()))

a.sort()
print(a[3])
# Out:
# Overwriting atcoder.py

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 4 18 25 20 9 13
# Out:
# Overwriting test1

# %%
# %cat test1 | python3 atcoder.py
# Out:
# 18

# %% [markdown]
# 18

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 95 96 97 98 99 100
# Out:
# Writing test2

# %%
# %cat test2 | python3 atcoder.py
# Out:
# 98

# %% [markdown]
# 98

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# 19 92 3 35 78 1
# Out:
# Writing test3

# %%
# %cat test3 | python3 atcoder.py
# Out:
# 35

# %% [markdown]
# 35

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。
