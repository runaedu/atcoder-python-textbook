# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# ゾロ目数<p>
# 問題文と提出先　https://atcoder.jp/contests/arc046/tasks/arc046_a

# %%
# %%writefile atcoder.py
import math
n=int(input())
s=""
num=math.ceil(n/9)
for i in range(num):
  if n%9==0:
    s+=str(9)
  else:
    s+=str(n%9)  
print(s)
# Out:
# Overwriting atcoder.py

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 1
# Out:
# Overwriting test1

# %%
# %cat test1 | python3 atcoder.py
# Out:
# 1

# %% [markdown]
# 1

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 11
# Out:
# Writing test2

# %%
# %cat test2 | python3 atcoder.py
# Out:
# 22

# %% [markdown]
# 22

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# 50
# Out:
# Writing test3

# %%
# %cat test3 | python3 atcoder.py
# Out:
# 555555

# %% [markdown]
# 555555

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A
