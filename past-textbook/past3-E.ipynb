# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# スプリンクラー<p>
# 問題文と提出先　https://atcoder.jp/contests/past202005-open/tasks/past202005_e<p>
# 隣接リストを使用したワークブックです。<p>
# make_edge関数を作ってみました。

# %%
# %%writefile atcoder.py
def in2ilist():
  return list(map(int,input().split()))

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e


N,M,Q=in2ilist()
graph=make_edge(N,M)

C=in2ilist()

####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 3 2 3
# 1 2
# 2 3
# 5 10 15
# 1 2
# 2 1 20
# 1 1

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# 10
# 10
# 10

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 30 10 20
# 11 13
# 30 14
# 6 4
# 7 23
# 30 8
# 17 4
# 6 23
# 24 18
# 26 25
# 9 3
# 18 4 36 46 28 16 34 19 37 23 25 7 24 16 17 41 24 38 6 29 10 33 38 25 47 8 13 8 42 40
# 2 1 9
# 1 8
# 1 9
# 2 20 24
# 2 26 18
# 1 20
# 1 26
# 2 24 31
# 1 4
# 2 21 27
# 1 25
# 1 29
# 2 10 14
# 2 2 19
# 2 15 36
# 2 28 6
# 2 13 5
# 1 12
# 1 11
# 2 14 43

# %%
# %cat test2 | python3 atcoder.py

# %% [markdown]
# 18
# 19
# 37
# 29
# 8
# 24
# 18
# 25
# 46
# 10
# 18
# 42
# 23
# 4
# 17
# 8
# 24
# 7
# 25
# 16

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e
