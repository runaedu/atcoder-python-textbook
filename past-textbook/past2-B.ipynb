# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# 多数決<p>
# 問題文と提出先　 https://atcoder.jp/contests/past202004-open/tasks/past202004_b

# %%
# %%writefile atcoder.py

S=input()
n=len(S)

####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# abbc

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# b

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# cacca

# %%
# %cat test2 | python3 atcoder.py

# %% [markdown]
# c

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# b

# %%
# %cat test3 | python3 atcoder.py

# %% [markdown]
# b

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。
