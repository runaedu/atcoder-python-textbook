# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# SNSのログ<p>
# 問題文と提出先　https://atcoder.jp/contests/past201912-open/tasks/past201912_e<p>
# 隣接行列を使用したワークブックです。<p>
# True Falseの代わりに、'Y' 'N'を使いましょう。

# %%
# %%writefile atcoder.py
def in2ilist():
  return list(map(int,input().split()))


N,Q=in2ilist()
graph=[]
for i in range(N):
  graph.append('N' * N )

####
####
for i in range(N): print(graph[i])

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 6 7
# 1 1 2
# 1 2 3
# 1 3 4
# 1 1 5
# 1 5 6
# 3 1
# 2 6

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# NYYNYY
# NNYNNN
# NNNYNN
# NNNNNN
# NNNNNY
# YNNNYN

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e
