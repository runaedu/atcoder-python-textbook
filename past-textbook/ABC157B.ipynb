# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# Bingo<p>
# 問題文と提出先　 https://atcoder.jp/contests/abc157/tasks/abc157_b

# %% [markdown]
# 本文と違い、2次元配列を読み込む専用の関数を準備します。<p>
# def in2ihw(_h): <p>

# %%
# %%writefile atcoder.py
def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

A=in2ihw(3)
n=int(input())
b=[]
for _ in range(n):
  _b=int(input())
  b.append(_b)

####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 84 97 66
# 79 89 11
# 61 59 7
# 7
# 89
# 7
# 87
# 79
# 24
# 84
# 30

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# Yes

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 41 7 46
# 26 89 2
# 78 92 8
# 5
# 6
# 45
# 16
# 57
# 17

# %%
# %cat test2 | python3 atcoder.py

# %% [markdown]
# No

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# 60 88 34
# 92 41 43
# 65 73 48
# 10
# 60
# 43
# 88
# 11
# 48
# 73
# 65
# 41
# 92
# 34

# %%
# %cat test3 | python3 atcoder.py

# %% [markdown]
# Yes

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。
