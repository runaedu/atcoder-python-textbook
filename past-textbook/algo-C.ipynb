# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# 巡回セールスマン問題<p>
# 問題文と提出先 https://atcoder.jp/contests/typical-algorithm/tasks/typical_algorithm_c<p>
# よく使いそうな関数を、Toolsにまとめておきます。コンテスト前にファイルを作っておいて、入れておくと便利です。<p>

# %%
# %%writefile atcoder.py
from collections import deque
import sys
sys.setrecursionlimit(1000000)

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def has_bit(n,i):
  return (n & (1<<i) > 0)

N = int(input())
A = in2ihw(N)

####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 4
# 0 3 1 4
# 1 0 5 9
# 2 6 0 5
# 3 5 8 0

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# 13

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
from collections import deque
import sys
sys.setrecursionlimit(1000000)

def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e

def make_2d(_h,_w,_init):
    _a=[]
    for _ in range(_h):
        _a.append([_init]*_w)
    return _a

def make_1d_none(_h):
    _a=[]
    for _ in range(_h):
        _a.append([])
    return _a


def has_bit(n,i):
  return (n & (1<<i) > 0)
